# %%
import requests
import pandas
import bs4
from time import sleep

# %%
numOfRows = 10
mesur_dy = '20211224'

# %%
def getApiData(search_date):
    url = 'http://apis.data.go.kr/B551015/stableinsensor/getstableinsensor'
    params ={
        'serviceKey' : 'baqeCF8cCfMx5WmtK3AwDsBzETWRJRowQPZasRdqPVrsslUXL1Ub0owA6uQSva47uIZRMAxUUZpzL9M3PWSB4A=='
        , 'pageNo' : '1'
        , 'numOfRows' : numOfRows
        , 'mesur_dy' : search_date
        , 'place_seq' : '1'
        , '_type' : 'xml'
    }

    response = requests.get(url,params=params)
    return response

# %%
def makeDic(items, co2_list, dewPoint_list, fireYn_list, mesurDy_list, mesurTime_list, nh3_list, o2_list, placeNm_list, placeSeq_list, reh_list, temper_list) :

    for item in items :
        co2_list.append(item.find('co2').text)
        dewPoint_list.append(item.find('dewPoint').text)
        fireYn_list.append(item.find('fireYn').text)
        mesurDy_list.append(item.find('mesurDy').text)
        mesurTime_list.append(item.find('mesurTime').text)
        nh3_list.append(item.find('nh3').text)
        o2_list.append(item.find('o2').text)
        placeNm_list.append(item.find('placeNm').text)
        placeSeq_list.append(item.find('placeSeq').text)
        reh_list.append(item.find('reh').text)
        temper_list.append(item.find('temper').text)

    
    return co2_list, dewPoint_list, fireYn_list, mesurDy_list, mesurTime_list, nh3_list, o2_list, placeNm_list, placeSeq_list, reh_list, temper_list

# %%
co2_list =[]
dewPoint_list =[]
fireYn_list =[]
mesurDy_list =[]
mesurTime_list =[]
nh3_list =[]
o2_list =[]
placeNm_list =[]
placeSeq_list =[]
reh_list =[]
temper_list =[]

#데이터를 조회할 날짜 세팅
index = pandas.date_range(start='20230101', end='20240320')

data_list = index.strftime("%Y%m%d").tolist()

for search_date in data_list:
    # api로 데이터 받기
    try:
        response = getApiData(search_date)
    except:
        time.sleep()    

    print(response.text)

    #받은 데이터는 BeautifulSoup으로 변환
    bs_data=bs4.BeautifulSoup(response.text,'lxml-xml')

    # 조회된 데이터가 있는지 확인
    dataCnt = int(bs_data.find('totalCount').text)
    print(f'{search_date} 날짜의 데이터 수 : {dataCnt}')

    #데이터가 있다면 그 데이터를 딕셔너리로 변환
    if dataCnt > 0 :
        # 데이터가 있다면 모든 데이터를 다시 조회
        numOfRows = dataCnt
        response = getApiData(search_date)
        bs_data=bs4.BeautifulSoup(response.text,'lxml-xml')

        items = bs_data.findAll('item')
        # co2_list1, dewPoint_list1, fireYn_list1, mesurDy_list1, mesurTime_list1, nh3_list1, o2_list1, placeNm_list1, placeSeq_list1, reh_list1, temper_list1 = makeDic(items, co2_list, dewPoint_list, fireYn_list, mesurDy_list, mesurTime_list, nh3_list, o2_list, placeNm_list, placeSeq_list, reh_list, temper_list)
        co2_list, dewPoint_list, fireYn_list, mesurDy_list, mesurTime_list, nh3_list, o2_list, placeNm_list, placeSeq_list, reh_list, temper_list = makeDic(items, co2_list, dewPoint_list, fireYn_list, mesurDy_list, mesurTime_list, nh3_list, o2_list, placeNm_list, placeSeq_list, reh_list, temper_list)


    dic_data = {}

    dic_data['co2']= co2_list
    dic_data['dewPoint']= dewPoint_list
    dic_data['fireYn']= fireYn_list
    dic_data['mesurDy']= mesurDy_list
    dic_data['mesurTime']= mesurTime_list
    dic_data['nh3']= nh3_list
    dic_data['o2']= o2_list
    dic_data['placeNm']= placeNm_list
    dic_data['placeSeq']= placeSeq_list
    dic_data['reh']= reh_list
    dic_data['temper']= temper_list        

    print(len(co2_list))
    print(len(dewPoint_list))
    print(len(fireYn_list))
    print(len(mesurDy_list))
    print(len(mesurTime_list))
    print(len(nh3_list))
    print(len(o2_list))
    print(len(placeNm_list))
    print(len(placeSeq_list))
    print(len(reh_list))
    print(len(temper_list))

    df = pandas.DataFrame(dic_data)    
    df
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0000</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0002</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0004</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0006</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0008</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0010</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0012</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0014</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0016</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0018</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0020</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0022</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0024</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0026</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0028</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230101</mesurDy><mesurTime>0030</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>2023010 ...
# 20230101 날짜의 데이터 수 : 720
# 720
# 720
# 720
# 720
# 720
# 720
# 720
# 720
# 720
# 720
# 720
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2030</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2032</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2034</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2036</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2038</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2040</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2042</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2044</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2046</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2048</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2050</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2052</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2054</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2056</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2058</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230102</mesurDy><mesurTime>2100</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>2023010 ...
# 20230102 날짜의 데이터 수 : 720
# 1440
# 1440
# 1440
# 1440
# 1440
# 1440
# 1440
# 1440
# 1440
# 1440
# 1440
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0000</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0002</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0004</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0006</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0008</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0010</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0012</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0014</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0016</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0018</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0020</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0022</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0024</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0026</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0028</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230103</mesurDy><mesurTime>0030</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>2023010 ...
# 20230103 날짜의 데이터 수 : 720
# 2160
# 2160
# 2160
# 2160
# 2160
# 2160
# 2160
# 2160
# 2160
# 2160
# 2160
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0000</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0002</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0004</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0006</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0008</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0010</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0012</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0014</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0016</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0018</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0020</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0022</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0024</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0026</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0028</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230104</mesurDy><mesurTime>0030</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>2023010 ...
# 20230104 날짜의 데이터 수 : 720
# 2880
# 2880
# 2880
# 2880
# 2880
# 2880
# 2880
# 2880
# 2880
# 2880
# 2880
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0000</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0002</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0004</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0006</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0008</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0010</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0012</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0014</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0016</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0018</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0020</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0022</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0024</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0026</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0028</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230105</mesurDy><mesurTime>0030</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>2023010 ...
# 20230105 날짜의 데이터 수 : 720
# 3600
# 3600
# 3600
# 3600
# 3600
# 3600
# 3600
# 3600
# 3600
# 3600
# 3600
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0000</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0002</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0004</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0006</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0008</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0010</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0012</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0014</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0016</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0018</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0020</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0022</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0024</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0026</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0028</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>20230106</mesurDy><mesurTime>0030</mesurTime><nh3>0</nh3><o2>24.53</o2><placeNm>서울경마장</placeNm><placeSeq>1</placeSeq><reh>44.94</reh><temper>10.81</temper></item><item><co2>0</co2><dewPoint>-0.9558</dewPoint><fireYn>N</fireYn><mesurDy>2023010 ...
# 20230106 날짜의 데이터 수 : 720
# 4320
# 4320
# 4320
# 4320
# 4320
# 4320
# 4320
# 4320
# 4320
# 4320
# 4320
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:400, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     399     self.putheader(header, value)
# --> 400 self.endheaders()
#     402 # If we're given a body we start sending that in chunks.
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1326, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1325     raise CannotSendHeader()
# -> 1326 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1085, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1084 del self._buffer[:]
# -> 1085 self.send(msg)
#    1087 if message_body is not None:
#    1088
#    1089     # create a consistent interface to message_body
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1029, in HTTPConnection.send(self, data)
#    1028 if self.auto_open:
# -> 1029     self.connect()
#    1030 else:
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:238, in HTTPConnection.connect(self)
#     237 def connect(self) -> None:
# --> 238     self.sock = self._new_conn()
#     239     if self._tunnel_host:
#     240         # If we're tunneling it means we're connected to our proxy.
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:207, in HTTPConnection._new_conn(self)
#     206 except SocketTimeout as e:
# --> 207     raise ConnectTimeoutError(
#     208         self,
#     209         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     210     ) from e
#     212 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x000001F1076907D0>, 'Connection to apis.data.go.kr timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:847, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     845     new_e = ProtocolError("Connection aborted.", new_e)
# --> 847 retries = retries.increment(
#     848     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     849 )
#     850 retries.sleep()
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /B551015/stableinsensor/getstableinsensor?serviceKey=baqeCF8cCfMx5WmtK3AwDsBzETWRJRowQPZasRdqPVrsslUXL1Ub0owA6uQSva47uIZRMAxUUZpzL9M3PWSB4A%3D%3D&pageNo=1&numOfRows=720&mesur_dy=20230107&place_seq=1&_type=xml (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000001F1076907D0>, 'Connection to apis.data.go.kr timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[14], line 21
#      20 try:
# ---> 21     response = getApiData(search_date)
#      22 except:
#
# Cell In[3], line 12, in getApiData(search_date)
#       3 params ={
#       4     'serviceKey' : 'baqeCF8cCfMx5WmtK3AwDsBzETWRJRowQPZasRdqPVrsslUXL1Ub0owA6uQSva47uIZRMAxUUZpzL9M3PWSB4A=='
#       5     , 'pageNo' : '1'
#    (...)
#       9     , '_type' : 'xml'
#      10 }
# ---> 12 response = requests.get(url,params=params)
#      13 return response
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:507, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     506     if not isinstance(e.reason, NewConnectionError):
# --> 507         raise ConnectTimeout(e, request=request)
#     509 if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /B551015/stableinsensor/getstableinsensor?serviceKey=baqeCF8cCfMx5WmtK3AwDsBzETWRJRowQPZasRdqPVrsslUXL1Ub0owA6uQSva47uIZRMAxUUZpzL9M3PWSB4A%3D%3D&pageNo=1&numOfRows=720&mesur_dy=20230107&place_seq=1&_type=xml (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000001F1076907D0>, 'Connection to apis.data.go.kr timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 23
#      21     response = getApiData(search_date)
#      22 except:
# ---> 23     time.sleep()
#      25 print(response.text)
#      27 #받은 데이터는 BeautifulSoup으로 변환
#
# NameError: name 'time' is not defined

# %%
df.to_excel('horse2.xlsx', index=False)
